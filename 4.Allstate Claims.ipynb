# %% [markdown]
#  # Mini project 4 - History Kaggle Demo: Allstate Claims

# %% [markdown]
# #### This Week's Topic：Allstate Claims Severity

# %% [markdown]
# You can get the detailed information and download the data from the following link:<br/>
# https://www.kaggle.com/c/allstate-claims-severity
#
# Note: You need to sign up a Kaggle Account before you can download the data.

# %%
## Import the necessary packages
import pandas as pd
import numpy as np
import xgboost as xgb
import seaborn as sns
from sklearn.model_selection import KFold,GridSearchCV
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics, preprocessing, cross_validation
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
train_data = pd.read_csv('data/train.csv')
train_size = train_data.shape[0]
test_data = pd.read_csv('data/test.csv')
test_size = test_data.shape[0]

# %% [markdown]
# ## Merge train and test
#
# This will save our time on duplicating logics for train and test and will also ensure the transformations applied on train and test are the same.

# %%
full_data = pd.concat([train_data,test_data]).reset_index(drop=True)

# %% [markdown]
# ## Group features
#
# In this step we will group the features into different groups so we can preprocess them seperately afterward.

# %%
data_types = full_data.dtypes  
cat_cols = list(data_types[data_types=='object'].index)
con_cols = list(data_types[data_types=='int64'].index) + list(data_types[data_types=='float64'].index)

id_col = 'id'
target_col = 'loss'
con_cols.remove('id')
con_cols.remove('loss')

print ("Categorical features:", cat_cols)
print ( "Numerica features:", con_cols)
print ( "ID: %s, target: %s" %( id_col, target_col))
# Out:
# ('Categorical features:', ['cat1', 'cat10', 'cat100', 'cat101', 'cat102', 'cat103', 'cat104', 'cat105', 'cat106', 'cat107', 'cat108', 'cat109', 'cat11', 'cat110', 'cat111', 'cat112', 'cat113', 'cat114', 'cat115', 'cat116', 'cat12', 'cat13', 'cat14', 'cat15', 'cat16', 'cat17', 'cat18', 'cat19', 'cat2', 'cat20', 'cat21', 'cat22', 'cat23', 'cat24', 'cat25', 'cat26', 'cat27', 'cat28', 'cat29', 'cat3', 'cat30', 'cat31', 'cat32', 'cat33', 'cat34', 'cat35', 'cat36', 'cat37', 'cat38', 'cat39', 'cat4', 'cat40', 'cat41', 'cat42', 'cat43', 'cat44', 'cat45', 'cat46', 'cat47', 'cat48', 'cat49', 'cat5', 'cat50', 'cat51', 'cat52', 'cat53', 'cat54', 'cat55', 'cat56', 'cat57', 'cat58', 'cat59', 'cat6', 'cat60', 'cat61', 'cat62', 'cat63', 'cat64', 'cat65', 'cat66', 'cat67', 'cat68', 'cat69', 'cat7', 'cat70', 'cat71', 'cat72', 'cat73', 'cat74', 'cat75', 'cat76', 'cat77', 'cat78', 'cat79', 'cat8', 'cat80', 'cat81', 'cat82', 'cat83', 'cat84', 'cat85', 'cat86', 'cat87', 'cat88', 'cat89', 'cat9', 'cat90', 'cat91', 'cat92', 'cat93', 'cat94', 'cat95', 'cat96', 'cat97', 'cat98', 'cat99'])
# ('Numerica features:', ['cont1', 'cont10', 'cont11', 'cont12', 'cont13', 'cont14', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7', 'cont8', 'cont9'])
# ID: id, target: loss

# %% [markdown]
# 1. features are anonymous
# 2. features are all encoded
# 3. Not too many feature engineering things we can do, but still, you can try something:
# e.g. new_feature1 = cont5 +-*/ cont6

# %% [markdown]
# **Some References:**<br/>
# http://blog.kaggle.com/2017/02/27/allstate-claims-severity-competition-2nd-place-winners-interview-alexey-noskov/

# %% [markdown]
# ## Some Data Exploration

# %% [markdown]
# Here is a good post for data exploration:<br/>
# https://www.kaggle.com/sharmasanthosh/exploratory-study-on-ml-algorithms

# %%
#Plot count plot for all attributes in a 29x4 grid
n_cols = 4
n_rows = 29
for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,figsize=(12, 8))
    for j in range(n_cols):
        sns.countplot(x=cat_cols[i*n_cols+j], data=train, ax=ax[j])

#cat1 to cat72 have only two labels A and B. In most of the cases, B has very few entries
#cat73 to cat 108 have more than two labels
#cat109 to cat116 have many labels
# Out:
# /Users/Tree/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# Plot violin for all attributes in a 7x2 grid
# violin plot: a combination of box and density plots
n_cols = 2
n_rows = 7

for i in range(n_rows):
    fg,ax = plt.subplots(nrows=1,ncols=n_cols,figsize=(12, 8))
    for j in range(n_cols):
        sns.violinplot(y=con_cols[i*n_cols+j], data=train, ax=ax[j])

# %%
sns.violinplot(data=train,y=train["loss"])
plt.show()

# %%
#log1p function applies log(1+x) to all elements of the column
loss = np.log1p(train["loss"])
sns.violinplot(data=train,y=loss)
plt.show()

# Plot shows that skew is corrected to a large extent

# %%
corrmat = train[con_cols].corr()
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 9))
# Draw the heatmap using seaborn
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %% [markdown]
# Strong correlation is observed between several pairs. <br/>
# This represents an opportunity to reduce the feature set through transformations such as PCA. <br/>

# %% [markdown]
# ## Categorical features
# ### 1. Label Encoding (Factorizing)

# %%
LBL = preprocessing.LabelEncoder()
start=time.time()
LE_map=dict()
for cat_col in cat_cols:
    full_data[cat_col] = LBL.fit_transform(full_data[cat_col])
    LE_map[cat_col]=dict(zip(LBL.classes_, LBL.transform(LBL.classes_)))
print ('Label enconding finished in %f seconds' % (time.time()-start))
# Out:
# Label enconding finished in 37.003092 seconds

# %%
LE_map
# Out:
# {'cat1': {'A': 0, 'B': 1},
#  'cat10': {'A': 0, 'B': 1},
#  'cat100': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14},
#  'cat101': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14,
#   'Q': 15,
#   'R': 16,
#   'S': 17,
#   'U': 18},
#  'cat102': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'J': 8},
#  'cat103': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13},
#  'cat104': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14,
#   'P': 15,
#   'Q': 16},
#  'cat105': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14,
#   'P': 15,
#   'Q': 16,
#   'R': 17,
#   'S': 18,
#   'T': 19},
#  'cat106': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14,
#   'P': 15,
#   'Q': 16,
#   'R': 17},
#  'cat107': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14,
#   'P': 15,
#   'Q': 16,
#   'R': 17,
#   'S': 18,
#   'U': 19},
#  'cat108': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10},
#  'cat109': {'A': 0,
#   'AA': 1,
#   'AB': 2,
#   'AD': 3,
#   'AE': 4,
#   'AF': 5,
#   'AG': 6,
#   'AH': 7,
#   'AI': 8,
#   'AJ': 9,
#   'AK': 10,
#   'AL': 11,
#   'AM': 12,
#   'AN': 13,
#   'AO': 14,
#   'AP': 15,
#   'AQ': 16,
#   'AR': 17,
#   'AS': 18,
#   'AT': 19,
#   'AU': 20,
#   'AV': 21,
#   'AW': 22,
#   'AX': 23,
#   'AY': 24,
#   'B': 25,
#   'BA': 26,
#   'BB': 27,
#   'BC': 28,
#   'BD': 29,
#   'BE': 30,
#   'BF': 31,
#   'BG': 32,
#   'BH': 33,
#   'BI': 34,
#   'BJ': 35,
#   'BK': 36,
#   'BL': 37,
#   'BM': 38,
#   'BN': 39,
#   'BO': 40,
#   'BP': 41,
#   'BQ': 42,
#   'BR': 43,
#   'BS': 44,
#   'BT': 45,
#   'BU': 46,
#   'BV': 47,
#   'BX': 48,
#   'BY': 49,
#   'C': 50,
#   'CA': 51,
#   'CB': 52,
#   'CC': 53,
#   'CD': 54,
#   'CE': 55,
#   'CF': 56,
#   'CG': 57,
#   'CH': 58,
#   'CI': 59,
#   'CJ': 60,
#   'CK': 61,
#   'CL': 62,
#   'D': 63,
#   'E': 64,
#   'F': 65,
#   'G': 66,
#   'H': 67,
#   'I': 68,
#   'J': 69,
#   'K': 70,
#   'L': 71,
#   'M': 72,
#   'N': 73,
#   'O': 74,
#   'P': 75,
#   'Q': 76,
#   'R': 77,
#   'S': 78,
#   'T': 79,
#   'U': 80,
#   'V': 81,
#   'X': 82,
#   'Y': 83,
#   'ZZ': 84},
#  'cat11': {'A': 0, 'B': 1},
#  'cat110': {'A': 0,
#   'AA': 1,
#   'AB': 2,
#   'AC': 3,
#   'AD': 4,
#   'AE': 5,
#   'AF': 6,
#   'AG': 7,
#   'AH': 8,
#   'AI': 9,
#   'AJ': 10,
#   'AK': 11,
#   'AL': 12,
#   'AM': 13,
#   'AN': 14,
#   'AO': 15,
#   'AP': 16,
#   'AR': 17,
#   'AS': 18,
#   'AT': 19,
#   'AU': 20,
#   'AV': 21,
#   'AW': 22,
#   'AX': 23,
#   'AY': 24,
#   'B': 25,
#   'BA': 26,
#   'BB': 27,
#   'BC': 28,
#   'BD': 29,
#   'BE': 30,
#   'BF': 31,
#   'BG': 32,
#   'BH': 33,
#   'BI': 34,
#   'BJ': 35,
#   'BK': 36,
#   'BL': 37,
#   'BM': 38,
#   'BN': 39,
#   'BO': 40,
#   'BP': 41,
#   'BQ': 42,
#   'BR': 43,
#   'BS': 44,
#   'BT': 45,
#   'BU': 46,
#   'BV': 47,
#   'BW': 48,
#   'BX': 49,
#   'BY': 50,
#   'C': 51,
#   'CA': 52,
#   'CB': 53,
#   'CC': 54,
#   'CD': 55,
#   'CF': 56,
#   'CG': 57,
#   'CH': 58,
#   'CI': 59,
#   'CJ': 60,
#   'CK': 61,
#   'CL': 62,
#   'CM': 63,
#   'CN': 64,
#   'CO': 65,
#   'CP': 66,
#   'CQ': 67,
#   'CR': 68,
#   'CS': 69,
#   'CT': 70,
#   'CU': 71,
#   'CV': 72,
#   'CW': 73,
#   'CX': 74,
#   'CY': 75,
#   'D': 76,
#   'DA': 77,
#   'DB': 78,
#   'DC': 79,
#   'DD': 80,
#   'DE': 81,
#   'DF': 82,
#   'DG': 83,
#   'DH': 84,
#   'DI': 85,
#   'DJ': 86,
#   'DK': 87,
#   'DL': 88,
#   'DM': 89,
#   'DN': 90,
#   'DO': 91,
#   'DP': 92,
#   'DQ': 93,
#   'DR': 94,
#   'DS': 95,
#   'DT': 96,
#   'DU': 97,
#   'DV': 98,
#   'DW': 99,
#   'DX': 100,
#   'DY': 101,
#   'E': 102,
#   'EA': 103,
#   'EB': 104,
#   'ED': 105,
#   'EE': 106,
#   'EF': 107,
#   'EG': 108,
#   'EH': 109,
#   'EI': 110,
#   'EJ': 111,
#   'EK': 112,
#   'EL': 113,
#   'EM': 114,
#   'EN': 115,
#   'G': 116,
#   'H': 117,
#   'I': 118,
#   'J': 119,
#   'K': 120,
#   'L': 121,
#   'N': 122,
#   'O': 123,
#   'P': 124,
#   'Q': 125,
#   'R': 126,
#   'S': 127,
#   'T': 128,
#   'U': 129,
#   'V': 130,
#   'W': 131,
#   'X': 132,
#   'Y': 133},
#  'cat111': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'I': 7,
#   'K': 8,
#   'L': 9,
#   'M': 10,
#   'O': 11,
#   'Q': 12,
#   'S': 13,
#   'U': 14,
#   'W': 15,
#   'Y': 16},
#  'cat112': {'A': 0,
#   'AA': 1,
#   'AB': 2,
#   'AC': 3,
#   'AD': 4,
#   'AE': 5,
#   'AF': 6,
#   'AG': 7,
#   'AH': 8,
#   'AI': 9,
#   'AJ': 10,
#   'AK': 11,
#   'AL': 12,
#   'AM': 13,
#   'AN': 14,
#   'AO': 15,
#   'AP': 16,
#   'AQ': 17,
#   'AR': 18,
#   'AS': 19,
#   'AT': 20,
#   'AU': 21,
#   'AV': 22,
#   'AW': 23,
#   'AX': 24,
#   'AY': 25,
#   'B': 26,
#   'BA': 27,
#   'C': 28,
#   'D': 29,
#   'E': 30,
#   'F': 31,
#   'G': 32,
#   'H': 33,
#   'I': 34,
#   'J': 35,
#   'K': 36,
#   'L': 37,
#   'M': 38,
#   'N': 39,
#   'O': 40,
#   'P': 41,
#   'Q': 42,
#   'R': 43,
#   'S': 44,
#   'T': 45,
#   'U': 46,
#   'V': 47,
#   'W': 48,
#   'X': 49,
#   'Y': 50},
#  'cat113': {'A': 0,
#   'AA': 1,
#   'AB': 2,
#   'AC': 3,
#   'AD': 4,
#   'AE': 5,
#   'AF': 6,
#   'AG': 7,
#   'AH': 8,
#   'AI': 9,
#   'AJ': 10,
#   'AK': 11,
#   'AL': 12,
#   'AM': 13,
#   'AN': 14,
#   'AO': 15,
#   'AP': 16,
#   'AQ': 17,
#   'AR': 18,
#   'AS': 19,
#   'AT': 20,
#   'AU': 21,
#   'AV': 22,
#   'AW': 23,
#   'AX': 24,
#   'AY': 25,
#   'B': 26,
#   'BA': 27,
#   'BB': 28,
#   'BC': 29,
#   'BD': 30,
#   'BE': 31,
#   'BF': 32,
#   'BG': 33,
#   'BH': 34,
#   'BI': 35,
#   'BJ': 36,
#   'BK': 37,
#   'BL': 38,
#   'BM': 39,
#   'BN': 40,
#   'BO': 41,
#   'C': 42,
#   'E': 43,
#   'F': 44,
#   'G': 45,
#   'H': 46,
#   'I': 47,
#   'J': 48,
#   'K': 49,
#   'L': 50,
#   'M': 51,
#   'N': 52,
#   'O': 53,
#   'P': 54,
#   'Q': 55,
#   'R': 56,
#   'S': 57,
#   'T': 58,
#   'U': 59,
#   'V': 60,
#   'X': 61,
#   'Y': 62},
#  'cat114': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'I': 7,
#   'J': 8,
#   'L': 9,
#   'N': 10,
#   'O': 11,
#   'Q': 12,
#   'R': 13,
#   'S': 14,
#   'U': 15,
#   'V': 16,
#   'W': 17,
#   'X': 18},
#  'cat115': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8,
#   'J': 9,
#   'K': 10,
#   'L': 11,
#   'M': 12,
#   'N': 13,
#   'O': 14,
#   'P': 15,
#   'Q': 16,
#   'R': 17,
#   'S': 18,
#   'T': 19,
#   'U': 20,
#   'W': 21,
#   'X': 22},
#  'cat116': {'A': 0,
#   'AA': 1,
#   'AB': 2,
#   'AC': 3,
#   'AD': 4,
#   'AE': 5,
#   'AF': 6,
#   'AG': 7,
#   'AH': 8,
#   'AI': 9,
#   'AJ': 10,
#   'AK': 11,
#   'AL': 12,
#   'AM': 13,
#   'AN': 14,
#   'AO': 15,
#   'AP': 16,
#   'AQ': 17,
#   'AR': 18,
#   'AS': 19,
#   'AT': 20,
#   'AU': 21,
#   'AV': 22,
#   'AW': 23,
#   'AX': 24,
#   'AY': 25,
#   'B': 26,
#   'BA': 27,
#   'BB': 28,
#   'BC': 29,
#   'BD': 30,
#   'BE': 31,
#   'BF': 32,
#   'BG': 33,
#   'BH': 34,
#   'BI': 35,
#   'BJ': 36,
#   'BK': 37,
#   'BL': 38,
#   'BM': 39,
#   'BN': 40,
#   'BO': 41,
#   'BP': 42,
#   'BQ': 43,
#   'BR': 44,
#   'BS': 45,
#   'BT': 46,
#   'BU': 47,
#   'BV': 48,
#   'BW': 49,
#   'BX': 50,
#   'BY': 51,
#   'C': 52,
#   'CA': 53,
#   'CB': 54,
#   'CC': 55,
#   'CD': 56,
#   'CE': 57,
#   'CF': 58,
#   'CG': 59,
#   'CH': 60,
#   'CI': 61,
#   'CJ': 62,
#   'CK': 63,
#   'CL': 64,
#   'CM': 65,
#   'CN': 66,
#   'CO': 67,
#   'CP': 68,
#   'CQ': 69,
#   'CR': 70,
#   'CS': 71,
#   'CT': 72,
#   'CU': 73,
#   'CV': 74,
#   'CW': 75,
#   'CX': 76,
#   'CY': 77,
#   'D': 78,
#   'DA': 79,
#   'DB': 80,
#   'DC': 81,
#   'DD': 82,
#   'DE': 83,
#   'DF': 84,
#   'DG': 85,
#   'DH': 86,
#   'DI': 87,
#   'DJ': 88,
#   'DK': 89,
#   'DL': 90,
#   'DM': 91,
#   'DN': 92,
#   'DO': 93,
#   'DP': 94,
#   'DQ': 95,
#   'DR': 96,
#   'DS': 97,
#   'DT': 98,
#   'DU': 99,
#   'DV': 100,
#   'DW': 101,
#   'DX': 102,
#   'DY': 103,
#   'E': 104,
#   'EA': 105,
#   'EB': 106,
#   'EC': 107,
#   'ED': 108,
#   'EE': 109,
#   'EF': 110,
#   'EG': 111,
#   'EH': 112,
#   'EI': 113,
#   'EJ': 114,
#   'EK': 115,
#   'EL': 116,
#   'EM': 117,
#   'EN': 118,
#   'EO': 119,
#   'EP': 120,
#   'EQ': 121,
#   'ER': 122,
#   'ES': 123,
#   'ET': 124,
#   'EU': 125,
#   'EV': 126,
#   'EW': 127,
#   'EX': 128,
#   'EY': 129,
#   'F': 130,
#   'FA': 131,
#   'FB': 132,
#   'FC': 133,
#   'FD': 134,
#   'FE': 135,
#   'FF': 136,
#   'FG': 137,
#   'FH': 138,
#   'FI': 139,
#   'FJ': 140,
#   'FK': 141,
#   'FL': 142,
#   'FM': 143,
#   'FN': 144,
#   'FO': 145,
#   'FP': 146,
#   'FQ': 147,
#   'FR': 148,
#   'FS': 149,
#   'FT': 150,
#   'FU': 151,
#   'FV': 152,
#   'FW': 153,
#   'FX': 154,
#   'FY': 155,
#   'G': 156,
#   'GA': 157,
#   'GB': 158,
#   'GC': 159,
#   'GD': 160,
#   'GE': 161,
#   'GF': 162,
#   'GG': 163,
#   'GH': 164,
#   'GI': 165,
#   'GJ': 166,
#   'GK': 167,
#   'GL': 168,
#   'GM': 169,
#   'GN': 170,
#   'GO': 171,
#   'GP': 172,
#   'GQ': 173,
#   'GR': 174,
#   'GS': 175,
#   'GT': 176,
#   'GU': 177,
#   'GV': 178,
#   'GW': 179,
#   'GX': 180,
#   'GY': 181,
#   'H': 182,
#   'HA': 183,
#   'HB': 184,
#   'HC': 185,
#   'HD': 186,
#   'HE': 187,
#   'HF': 188,
#   'HG': 189,
#   'HH': 190,
#   'HI': 191,
#   'HJ': 192,
#   'HK': 193,
#   'HL': 194,
#   'HM': 195,
#   'HN': 196,
#   'HO': 197,
#   'HP': 198,
#   'HQ': 199,
#   'HR': 200,
#   'HS': 201,
#   'HT': 202,
#   'HU': 203,
#   'HV': 204,
#   'HW': 205,
#   'HX': 206,
#   'HY': 207,
#   'I': 208,
#   'IA': 209,
#   'IB': 210,
#   'IC': 211,
#   'ID': 212,
#   'IE': 213,
#   'IF': 214,
#   'IG': 215,
#   'IH': 216,
#   'II': 217,
#   'IJ': 218,
#   'IK': 219,
#   'IL': 220,
#   'IM': 221,
#   'IN': 222,
#   'IO': 223,
#   'IP': 224,
#   'IQ': 225,
#   'IR': 226,
#   'IS': 227,
#   'IT': 228,
#   'IU': 229,
#   'IV': 230,
#   'IW': 231,
#   'IX': 232,
#   'IY': 233,
#   'J': 234,
#   'JA': 235,
#   'JB': 236,
#   'JC': 237,
#   'JD': 238,
#   'JE': 239,
#   'JF': 240,
#   'JG': 241,
#   'JH': 242,
#   'JI': 243,
#   'JJ': 244,
#   'JK': 245,
#   'JL': 246,
#   'JM': 247,
#   'JN': 248,
#   'JO': 249,
#   'JP': 250,
#   'JQ': 251,
#   'JR': 252,
#   'JS': 253,
#   'JT': 254,
#   'JU': 255,
#   'JV': 256,
#   'JW': 257,
#   'JX': 258,
#   'JY': 259,
#   'K': 260,
#   'KA': 261,
#   'KB': 262,
#   'KC': 263,
#   'KD': 264,
#   'KE': 265,
#   'KF': 266,
#   'KG': 267,
#   'KH': 268,
#   'KI': 269,
#   'KJ': 270,
#   'KK': 271,
#   'KL': 272,
#   'KM': 273,
#   'KN': 274,
#   'KO': 275,
#   'KP': 276,
#   'KQ': 277,
#   'KR': 278,
#   'KS': 279,
#   'KT': 280,
#   'KU': 281,
#   'KV': 282,
#   'KW': 283,
#   'KX': 284,
#   'KY': 285,
#   'L': 286,
#   'LA': 287,
#   'LB': 288,
#   'LC': 289,
#   'LD': 290,
#   'LE': 291,
#   'LF': 292,
#   'LG': 293,
#   'LH': 294,
#   'LI': 295,
#   'LJ': 296,
#   'LK': 297,
#   'LL': 298,
#   'LM': 299,
#   'LN': 300,
#   'LO': 301,
#   'LP': 302,
#   'LQ': 303,
#   'LR': 304,
#   'LS': 305,
#   'LT': 306,
#   'LU': 307,
#   'LV': 308,
#   'LW': 309,
#   'LX': 310,
#   'LY': 311,
#   'M': 312,
#   'MA': 313,
#   'MB': 314,
#   'MC': 315,
#   'MD': 316,
#   'ME': 317,
#   'MF': 318,
#   'MG': 319,
#   'MH': 320,
#   'MI': 321,
#   'MJ': 322,
#   'MK': 323,
#   'ML': 324,
#   'MM': 325,
#   'MN': 326,
#   'MO': 327,
#   'MP': 328,
#   'MQ': 329,
#   'MR': 330,
#   'MS': 331,
#   'MT': 332,
#   'MU': 333,
#   'MV': 334,
#   'MW': 335,
#   'MX': 336,
#   'N': 337,
#   'O': 338,
#   'P': 339,
#   'Q': 340,
#   'R': 341,
#   'S': 342,
#   'T': 343,
#   'U': 344,
#   'V': 345,
#   'W': 346,
#   'X': 347,
#   'Y': 348},
#  'cat12': {'A': 0, 'B': 1},
#  'cat13': {'A': 0, 'B': 1},
#  'cat14': {'A': 0, 'B': 1},
#  'cat15': {'A': 0, 'B': 1},
#  'cat16': {'A': 0, 'B': 1},
#  'cat17': {'A': 0, 'B': 1},
#  'cat18': {'A': 0, 'B': 1},
#  'cat19': {'A': 0, 'B': 1},
#  'cat2': {'A': 0, 'B': 1},
#  'cat20': {'A': 0, 'B': 1},
#  'cat21': {'A': 0, 'B': 1},
#  'cat22': {'A': 0, 'B': 1},
#  'cat23': {'A': 0, 'B': 1},
#  'cat24': {'A': 0, 'B': 1},
#  'cat25': {'A': 0, 'B': 1},
#  'cat26': {'A': 0, 'B': 1},
#  'cat27': {'A': 0, 'B': 1},
#  'cat28': {'A': 0, 'B': 1},
#  'cat29': {'A': 0, 'B': 1},
#  'cat3': {'A': 0, 'B': 1},
#  'cat30': {'A': 0, 'B': 1},
#  'cat31': {'A': 0, 'B': 1},
#  'cat32': {'A': 0, 'B': 1},
#  'cat33': {'A': 0, 'B': 1},
#  'cat34': {'A': 0, 'B': 1},
#  'cat35': {'A': 0, 'B': 1},
#  'cat36': {'A': 0, 'B': 1},
#  'cat37': {'A': 0, 'B': 1},
#  'cat38': {'A': 0, 'B': 1},
#  'cat39': {'A': 0, 'B': 1},
#  'cat4': {'A': 0, 'B': 1},
#  'cat40': {'A': 0, 'B': 1},
#  'cat41': {'A': 0, 'B': 1},
#  'cat42': {'A': 0, 'B': 1},
#  'cat43': {'A': 0, 'B': 1},
#  'cat44': {'A': 0, 'B': 1},
#  'cat45': {'A': 0, 'B': 1},
#  'cat46': {'A': 0, 'B': 1},
#  'cat47': {'A': 0, 'B': 1},
#  'cat48': {'A': 0, 'B': 1},
#  'cat49': {'A': 0, 'B': 1},
#  'cat5': {'A': 0, 'B': 1},
#  'cat50': {'A': 0, 'B': 1},
#  'cat51': {'A': 0, 'B': 1},
#  'cat52': {'A': 0, 'B': 1},
#  'cat53': {'A': 0, 'B': 1},
#  'cat54': {'A': 0, 'B': 1},
#  'cat55': {'A': 0, 'B': 1},
#  'cat56': {'A': 0, 'B': 1},
#  'cat57': {'A': 0, 'B': 1},
#  'cat58': {'A': 0, 'B': 1},
#  'cat59': {'A': 0, 'B': 1},
#  'cat6': {'A': 0, 'B': 1},
#  'cat60': {'A': 0, 'B': 1},
#  'cat61': {'A': 0, 'B': 1},
#  'cat62': {'A': 0, 'B': 1},
#  'cat63': {'A': 0, 'B': 1},
#  'cat64': {'A': 0, 'B': 1},
#  'cat65': {'A': 0, 'B': 1},
#  'cat66': {'A': 0, 'B': 1},
#  'cat67': {'A': 0, 'B': 1},
#  'cat68': {'A': 0, 'B': 1},
#  'cat69': {'A': 0, 'B': 1},
#  'cat7': {'A': 0, 'B': 1},
#  'cat70': {'A': 0, 'B': 1},
#  'cat71': {'A': 0, 'B': 1},
#  'cat72': {'A': 0, 'B': 1},
#  'cat73': {'A': 0, 'B': 1, 'C': 2},
#  'cat74': {'A': 0, 'B': 1, 'C': 2},
#  'cat75': {'A': 0, 'B': 1, 'C': 2},
#  'cat76': {'A': 0, 'B': 1, 'C': 2},
#  'cat77': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat78': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat79': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat8': {'A': 0, 'B': 1},
#  'cat80': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat81': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat82': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat83': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat84': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat85': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat86': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat87': {'A': 0, 'B': 1, 'C': 2, 'D': 3},
#  'cat88': {'A': 0, 'B': 1, 'D': 2, 'E': 3},
#  'cat89': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8},
#  'cat9': {'A': 0, 'B': 1},
#  'cat90': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6},
#  'cat91': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7},
#  'cat92': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8},
#  'cat93': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4},
#  'cat94': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6},
#  'cat95': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4},
#  'cat96': {'A': 0,
#   'B': 1,
#   'C': 2,
#   'D': 3,
#   'E': 4,
#   'F': 5,
#   'G': 6,
#   'H': 7,
#   'I': 8},
#  'cat97': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6},
#  'cat98': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4},
#  'cat99': {'C': 0,
#   'D': 1,
#   'E': 2,
#   'F': 3,
#   'G': 4,
#   'H': 5,
#   'I': 6,
#   'J': 7,
#   'K': 8,
#   'M': 9,
#   'N': 10,
#   'O': 11,
#   'P': 12,
#   'R': 13,
#   'S': 14,
#   'T': 15,
#   'U': 16}}

# %% [markdown]
# ### 2. One Hot Encoding (get dummies)
#
# OHE can be done by either Pandas' get_dummies() or SK Learn's OneHotEncoder.
#
# * get_dummies is easier to implement (can be used directly on raw categorical features, i.e. strings), but it takes longer time and is not memory efficient.
#
# * OneHotEncoder requires the features being converted to numeric, which has already been done by LabelEncoder in previous step, and is much more efficient (7x faster).
#
# * We will convert the OHE's results to a sparse matrix which uses way less memory as compared to dense matrix. However, not all algorithms and packagers support sparse matrix, e.g. Keras. In that case, we'll need to use other tricks to make it work.

# %%
OHE = preprocessing.OneHotEncoder(sparse=True)
start=time.time()
full_data_sparse=OHE.fit_transform(full_data[cat_cols])
print ('One-hot-encoding finished in %f seconds' % (time.time()-start))

print (full_data_sparse.shape)
# Out:
# One-hot-encoding finished in 3.714171 seconds
# (313864, 1176)

# %% [markdown]
# ## Numeric features
#
# Because feature with the largest range will dominate the outcome results and we’ll obtain less accurate predictions, we will apply two preprocessings on numeric features:
#
# 1. Apply box-cox transformations for skewed numeric features.
#
# 2. Scale numeric features so they will fall in the range between 0 and 1.
#
# Please be advised that these preprocessings are not necessary for tree-based models, e.g. XGBoost. However, linear or linear-based models may benefit from them. Rule of thumb I follow here is any algorithm that computes distance or assumes normality （KNN,PCA), scale your features!!!
#
# https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e

# %% [markdown]
# ** Calculate skewness of each numeric features: **

# %%
from scipy.stats import skew, boxcox
skewed_cols = full_data[con_cols].apply(lambda x: skew(x.dropna()))
print (skewed_cols.sort_values())
# Out:
# cont2    -0.101841
# cont9    -0.012046
# cont3    -0.007023
# cont1     0.004049
# cont10    0.020122
# cont11    0.023397
# cont12    0.024871
# cont6     0.038833
# cont4     0.051627
# cont7     0.054710
# cont14    0.068549
# cont13    0.092823
# cont8     0.124111
# cont5     0.205682
# dtype: float64

# %% [markdown]
# ** Apply box-cox transformations: **<br/>
# https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.stats.boxcox.html

# %%
skewed_cols = skewed_cols[abs(skewed_cols) > 0.25].index.values
for skewed_col in skewed_cols:
    full_data[skewed_col], lam = boxcox(full_data[skewed_col] + 1)

# %% [markdown]
# ** Apply Standard Scaling:**<br/>
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
SSL = preprocessing.StandardScaler()
for con_col in con_cols:
     full_data[con_col] = SSL.fit_transform(full_data[con_col].values.reshape(-1,1))

# %% [markdown]
# ## Model Building: Xgboost

# %% [markdown]
# The Xgboost API:<br/>
# http://xgboost.readthedocs.io/en/latest/python/python_api.html<br/>
# https://github.com/dmlc/xgboost/blob/master/doc/parameter.md

# %% [markdown]
# More information for xgboost parameters:<br/>
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %%
from scipy import sparse
full_data_sparse = sparse.hstack((full_data_sparse,full_data[con_cols]), format='csr')
print (full_data_sparse.shape)
# Out:
# (313864, 1190)

# %% [markdown]
# About sparse matrix:<br/>
# https://en.wikipedia.org/wiki/Sparse_matrix#Compressed_sparse_row_.28CSR.2C_CRS_or_Yale_format.29

# %%
train_x = full_data_sparse[:train_size]
test_x = full_data_sparse[train_size:]
train_y = np.log(full_data[:train_size].loss.values + 200)
ID = full_data.id[:train_size].values

# %% [markdown]
# Here is another experience tip:<br/>
# When the problem is regression problem and the evaluation metrics is mse/mae, use the following metrics will get a better result.

# %%
def logregobj(labels, preds):
    con = 2
    x =preds-labels
    grad =con*x / (np.abs(x)+con)
    hess =con**2 / (np.abs(x)+con)**2
    return grad, hess 

def log_mae(y,yhat):
    return mean_absolute_error(np.exp(y), np.exp(yhat))

log_mae_scorer = metrics.make_scorer(log_mae, greater_is_better = False)

# %%
def search_model(train_x, train_y, est, param_grid, n_jobs, cv, refit=False):
##Grid Search for the best model
    model = GridSearchCV(estimator  = est,
                                     param_grid = param_grid,
                                     scoring    = log_mae_scorer,
                                     verbose    = 10,
                                     n_jobs  = n_jobs,
                                     iid        = True,
                                     refit    = refit,
                                     cv      = cv)
    # Fit Grid Search Model
    model.fit(train_x, train_y)
    print("Best score: %0.3f" % model.best_score_)
    print("Best parameters set:", model.best_params_)
    print("Scores:", model.grid_scores_)
    return model

# %%
param_grid = {'objective':[logregobj],
              'learning_rate':[0.02, 0.04, 0.06, 0.08],
              'n_estimators':[1500],
              'max_depth': [9],
              'min_child_weight':[50],
              'subsample': [0.78],
              'colsample_bytree':[0.67],
              'gamma':[0.9],
              'nthread': [-1],
              'seed' : [1234]}

model = search_model(train_x,
                     train_y,
                     xgb.XGBRegressor(),
                     param_grid,
                     n_jobs = 1,
                     cv = 4,
                     refit = True)
# Out:
# Fitting 4 folds for each of 1 candidates, totalling 4 fits
# [CV] seed=1234, n_estimators=1500, nthread=-1, objective=<function logregobj at 0x115acc6a8>, subsample=0.78, colsample_bytree=0.67, max_depth=9, min_child_weight=50, learning_rate=0.02, gamma=0.9
# [CV]  seed=1234, n_estimators=1500, nthread=-1, objective=<function logregobj at 0x115acc6a8>, subsample=0.78, colsample_bytree=0.67, max_depth=9, min_child_weight=50, learning_rate=0.02, gamma=0.9, score=-1135.573586, total=30.2min
# [CV] seed=1234, n_estimators=1500, nthread=-1, objective=<function logregobj at 0x115acc6a8>, subsample=0.78, colsample_bytree=0.67, max_depth=9, min_child_weight=50, learning_rate=0.02, gamma=0.9
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 30.9min remaining:    0.0s
# [CV]  seed=1234, n_estimators=1500, nthread=-1, objective=<function logregobj at 0x115acc6a8>, subsample=0.78, colsample_bytree=0.67, max_depth=9, min_child_weight=50, learning_rate=0.02, gamma=0.9, score=-1139.255827, total=34.2min
# [CV] seed=1234, n_estimators=1500, nthread=-1, objective=<function logregobj at 0x115acc6a8>, subsample=0.78, colsample_bytree=0.67, max_depth=9, min_child_weight=50, learning_rate=0.02, gamma=0.9
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 65.8min remaining:    0.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-6d988e75ed5e> in <module>()
#      16                      n_jobs = 1,
#      17                      cv = 4,
# ---> 18                      refit = True)
#
# <ipython-input-78-88b5313d9359> in search_model(train_x, train_y, est, param_grid, n_jobs, cv, refit)
#      10                                      cv      = cv)
#      11     # Fit Grid Search Model
# ---> 12     model.fit(train_x, train_y)
#      13     print("Best score: %0.3f" % model.best_score_)
#      14     print("Best parameters set:", model.best_params_)
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_search.py in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# --> 564           for parameters in parameter_iterable
#     565           for train, test in cv_iter)
#     566
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/xgboost-0.6-py3.5.egg/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose)
#     254                               early_stopping_rounds=early_stopping_rounds,
#     255                               evals_result=evals_result, obj=obj, feval=feval,
# --> 256                               verbose_eval=verbose)
#     257
#     258         if evals_result:
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/xgboost-0.6-py3.5.egg/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/xgboost-0.6-py3.5.egg/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/xgboost-0.6-py3.5.egg/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     821             pred = self.predict(dtrain)
#     822             grad, hess = fobj(pred, dtrain)
# --> 823             self.boost(dtrain, grad, hess)
#     824
#     825     def boost(self, dtrain, grad, hess):
#
# /Users/chenguang/anaconda/envs/py35/lib/python3.5/site-packages/xgboost-0.6-py3.5.egg/xgboost/core.py in boost(self, dtrain, grad, hess)
#     845                                                c_array(ctypes.c_float, grad),
#     846                                                c_array(ctypes.c_float, hess),
# --> 847                                                len(grad)))
#     848
#     849     def eval_set(self, evals, iteration=0, feval=None):
#
# KeyboardInterrupt:

# %%
rgr = xgb.XGBRegressor(seed = 1234, 
                       learning_rate = 0.01, # smaller, better results, more time
                       n_estimators = 1500, # Number of boosted trees to fit.
                       max_depth=9, # the maximum depth of a tree
                       min_child_weight=50,
                       colsample_bytree=0.67, # the fraction of columns to be randomly samples for each tree
                       subsample=0.78, # the fraction of observations to be randomly samples for each tree
                       gamma=0.9, # Minimum loss reduction required to make a further partition on a leaf node of the tree, 
                       # the larger, the more conservative 
                       nthread = -1, # Number of parallel threads used to run xgboost.
                       silent = False # Whether to print messages while running boosting.
                      )
rgr.fit(train_x, train_y)
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.67,
#        gamma=0.9, learning_rate=0.01, max_delta_step=0, max_depth=9,
#        min_child_weight=50, missing=None, n_estimators=1500, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=1234, silent=False, subsample=0.78)

# %%
pred_y = np.exp(rgr.predict(test_x)) - 200

results = pd.DataFrame()
results['id'] = full_data[train_size:].id
results['loss'] = pred_y
results.to_csv("output/sub.csv", index=False)
print ("Submission created.")
# Out:
# Submission created.

# %% [markdown]
# Here I submit this sub.csv to Kaggle, and the Public Score is 1121.50666, the ranking is 646/3055, not bad.
# There are still some other things you can do to improve this score:)

# %%
plt.bar(range(len(rgr.feature_importances_)), rgr.feature_importances_)
plt.show()

# %%
xgb.plot_importance(rgr,max_num_features=5,importance_type='weight')

# %%
np.argsort(rgr.feature_importances_)
# Out:
# array([ 601,  620,  621, ..., 1182, 1187, 1181])

# %% [markdown]
# You can refer to the following article to see how to select the features according to the feature importance: <br/>
# http://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/

# %% [markdown]
# ## Some Feature Combination

# %% [markdown]
# Here I will add some new features from the combination of some features.

# %% [markdown]
# ** Continous Features**

# %%
train_test = pd.concat([train,test]).reset_index(drop=True)
## this part create two new features
# arithmetic mean
train_test["cont15"] = train_test["cont1"] + train_test["cont2"] + train_test["cont3"] + train_test["cont4"] + train_test["cont5"] + train_test["cont6"] + train_test["cont7"] + train_test["cont8"] + train_test["cont9"] + train_test["cont10"] + train_test["cont11"] + train_test["cont12"] + train_test["cont13"] + train_test["cont14"]
train_test["cont15"] = train_test["cont15"]/14
# Geometric mean
train_test["cont16"] = train_test["cont1"] * train_test["cont2"] * train_test["cont3"] * train_test["cont4"] * train_test["cont5"] * train_test["cont6"] * train_test["cont7"] * train_test["cont8"] * train_test["cont9"] * train_test["cont10"] * train_test["cont11"] * train_test["cont12"] * train_test["cont13"] * train_test["cont14"]
train_test["cont16"] = train_test["cont15"]**(1/14)

## this part do the same function with standard scaling and box-cox transformation
train_test["cont1"] = np.sqrt(preprocessing.minmax_scale(train_test["cont1"]))
train_test["cont4"] = np.sqrt(preprocessing.minmax_scale(train_test["cont4"]))
train_test["cont5"] = np.sqrt(preprocessing.minmax_scale(train_test["cont5"]))
train_test["cont8"] = np.sqrt(preprocessing.minmax_scale(train_test["cont8"]))
train_test["cont10"] = np.sqrt(preprocessing.minmax_scale(train_test["cont10"]))
train_test["cont11"] = np.sqrt(preprocessing.minmax_scale(train_test["cont11"]))
train_test["cont12"] = np.sqrt(preprocessing.minmax_scale(train_test["cont12"]))

train_test["cont6"] = np.log(preprocessing.minmax_scale(train_test["cont6"])+0000.1)
train_test["cont7"] = np.log(preprocessing.minmax_scale(train_test["cont7"])+0000.1)
train_test["cont9"] = np.log(preprocessing.minmax_scale(train_test["cont9"])+0000.1)
train_test["cont13"] = np.log(preprocessing.minmax_scale(train_test["cont13"])+0000.1)
train_test["cont14"]=(np.maximum(train_test["cont14"]-0.179722,0)/0.665122)**0.25

# %%
skewed_cols_2 = train_test[con_cols].apply(lambda x: skew(x.dropna()))
print (skewed_cols_2.sort_values())
# Out:
# cont14   -0.359569
# cont2    -0.311146
# cont4    -0.234536
# cont6    -0.192447
# cont1    -0.137809
# cont10   -0.081397
# cont11   -0.058008
# cont12   -0.051769
# cont3    -0.007023
# cont5    -0.001885
# cont13    0.000933
# cont8     0.016604
# cont7     0.053462
# cont9     0.242141
# dtype: float64

# %% [markdown]
# ** Categorical Features**
#
# because we use tree-based model, we need to restrict split complexity , so we need cat feature combination

# %%
COMB_FEATURE = 'cat80,cat87,cat57,cat12,cat79,cat10,cat7,cat89,cat2,cat72,' \
               'cat81,cat11,cat1,cat13,cat9,cat3,cat16,cat90,cat23,cat36,' \
               'cat73,cat103,cat40,cat28,cat111,cat6,cat76,cat50,cat5,' \
               'cat4,cat14,cat38,cat24,cat82,cat25'.split(',')
# a, b
# A, B
# -> 4: aA,aB,bA,bB

# %%
import itertools
for comb in itertools.combinations(COMB_FEATURE, 2):
    feat = comb[0] + "_" + comb[1]
    train_test[feat] = train_test[comb[0]] + train_test[comb[1]]
    print('Combining Columns:', feat)
# Out:
# Combining Columns: cat80_cat87
# Combining Columns: cat80_cat57
# Combining Columns: cat80_cat12
# Combining Columns: cat80_cat79
# Combining Columns: cat80_cat10
# Combining Columns: cat80_cat7
# Combining Columns: cat80_cat89
# Combining Columns: cat80_cat2
# Combining Columns: cat80_cat72
# Combining Columns: cat80_cat81
# Combining Columns: cat80_cat11
# Combining Columns: cat80_cat1
# Combining Columns: cat80_cat13
# Combining Columns: cat80_cat9
# Combining Columns: cat80_cat3
# Combining Columns: cat80_cat16
# Combining Columns: cat80_cat90
# Combining Columns: cat80_cat23
# Combining Columns: cat80_cat36
# Combining Columns: cat80_cat73
# Combining Columns: cat80_cat103
# Combining Columns: cat80_cat40
# Combining Columns: cat80_cat28
# Combining Columns: cat80_cat111
# Combining Columns: cat80_cat6
# Combining Columns: cat80_cat76
# Combining Columns: cat80_cat50
# Combining Columns: cat80_cat5
# Combining Columns: cat80_cat4
# Combining Columns: cat80_cat14
# Combining Columns: cat80_cat38
# Combining Columns: cat80_cat24
# Combining Columns: cat80_cat82
# Combining Columns: cat80_cat25
# Combining Columns: cat87_cat57
# Combining Columns: cat87_cat12
# Combining Columns: cat87_cat79
# Combining Columns: cat87_cat10
# Combining Columns: cat87_cat7
# Combining Columns: cat87_cat89
# Combining Columns: cat87_cat2
# Combining Columns: cat87_cat72
# Combining Columns: cat87_cat81
# Combining Columns: cat87_cat11
# Combining Columns: cat87_cat1
# Combining Columns: cat87_cat13
# Combining Columns: cat87_cat9
# Combining Columns: cat87_cat3
# Combining Columns: cat87_cat16
# Combining Columns: cat87_cat90
# Combining Columns: cat87_cat23
# Combining Columns: cat87_cat36
# Combining Columns: cat87_cat73
# Combining Columns: cat87_cat103
# Combining Columns: cat87_cat40
# Combining Columns: cat87_cat28
# Combining Columns: cat87_cat111
# Combining Columns: cat87_cat6
# Combining Columns: cat87_cat76
# Combining Columns: cat87_cat50
# Combining Columns: cat87_cat5
# Combining Columns: cat87_cat4
# Combining Columns: cat87_cat14
# Combining Columns: cat87_cat38
# Combining Columns: cat87_cat24
# Combining Columns: cat87_cat82
# Combining Columns: cat87_cat25
# Combining Columns: cat57_cat12
# Combining Columns: cat57_cat79
# Combining Columns: cat57_cat10
# Combining Columns: cat57_cat7
# Combining Columns: cat57_cat89
# Combining Columns: cat57_cat2
# Combining Columns: cat57_cat72
# Combining Columns: cat57_cat81
# Combining Columns: cat57_cat11
# Combining Columns: cat57_cat1
# Combining Columns: cat57_cat13
# Combining Columns: cat57_cat9
# Combining Columns: cat57_cat3
# Combining Columns: cat57_cat16
# Combining Columns: cat57_cat90
# Combining Columns: cat57_cat23
# Combining Columns: cat57_cat36
# Combining Columns: cat57_cat73
# Combining Columns: cat57_cat103
# Combining Columns: cat57_cat40
# Combining Columns: cat57_cat28
# Combining Columns: cat57_cat111
# Combining Columns: cat57_cat6
# Combining Columns: cat57_cat76
# Combining Columns: cat57_cat50
# Combining Columns: cat57_cat5
# Combining Columns: cat57_cat4
# Combining Columns: cat57_cat14
# Combining Columns: cat57_cat38
# Combining Columns: cat57_cat24
# Combining Columns: cat57_cat82
# Combining Columns: cat57_cat25
# Combining Columns: cat12_cat79
# Combining Columns: cat12_cat10
# Combining Columns: cat12_cat7
# Combining Columns: cat12_cat89
# Combining Columns: cat12_cat2
# Combining Columns: cat12_cat72
# Combining Columns: cat12_cat81
# Combining Columns: cat12_cat11
# Combining Columns: cat12_cat1
# Combining Columns: cat12_cat13
# Combining Columns: cat12_cat9
# Combining Columns: cat12_cat3
# Combining Columns: cat12_cat16
# Combining Columns: cat12_cat90
# Combining Columns: cat12_cat23
# Combining Columns: cat12_cat36
# Combining Columns: cat12_cat73
# Combining Columns: cat12_cat103
# Combining Columns: cat12_cat40
# Combining Columns: cat12_cat28
# Combining Columns: cat12_cat111
# Combining Columns: cat12_cat6
# Combining Columns: cat12_cat76
# Combining Columns: cat12_cat50
# Combining Columns: cat12_cat5
# Combining Columns: cat12_cat4
# Combining Columns: cat12_cat14
# Combining Columns: cat12_cat38
# Combining Columns: cat12_cat24
# Combining Columns: cat12_cat82
# Combining Columns: cat12_cat25
# Combining Columns: cat79_cat10
# Combining Columns: cat79_cat7
# Combining Columns: cat79_cat89
# Combining Columns: cat79_cat2
# Combining Columns: cat79_cat72
# Combining Columns: cat79_cat81
# Combining Columns: cat79_cat11
# Combining Columns: cat79_cat1
# Combining Columns: cat79_cat13
# Combining Columns: cat79_cat9
# Combining Columns: cat79_cat3
# Combining Columns: cat79_cat16
# Combining Columns: cat79_cat90
# Combining Columns: cat79_cat23
# Combining Columns: cat79_cat36
# Combining Columns: cat79_cat73
# Combining Columns: cat79_cat103
# Combining Columns: cat79_cat40
# Combining Columns: cat79_cat28
# Combining Columns: cat79_cat111
# Combining Columns: cat79_cat6
# Combining Columns: cat79_cat76
# Combining Columns: cat79_cat50
# Combining Columns: cat79_cat5
# Combining Columns: cat79_cat4
# Combining Columns: cat79_cat14
# Combining Columns: cat79_cat38
# Combining Columns: cat79_cat24
# Combining Columns: cat79_cat82
# Combining Columns: cat79_cat25
# Combining Columns: cat10_cat7
# Combining Columns: cat10_cat89
# Combining Columns: cat10_cat2
# Combining Columns: cat10_cat72
# Combining Columns: cat10_cat81
# Combining Columns: cat10_cat11
# Combining Columns: cat10_cat1
# Combining Columns: cat10_cat13
# Combining Columns: cat10_cat9
# Combining Columns: cat10_cat3
# Combining Columns: cat10_cat16
# Combining Columns: cat10_cat90
# Combining Columns: cat10_cat23
# Combining Columns: cat10_cat36
# Combining Columns: cat10_cat73
# Combining Columns: cat10_cat103
# Combining Columns: cat10_cat40
# Combining Columns: cat10_cat28
# Combining Columns: cat10_cat111
# Combining Columns: cat10_cat6
# Combining Columns: cat10_cat76
# Combining Columns: cat10_cat50
# Combining Columns: cat10_cat5
# Combining Columns: cat10_cat4
# Combining Columns: cat10_cat14
# Combining Columns: cat10_cat38
# Combining Columns: cat10_cat24
# Combining Columns: cat10_cat82
# Combining Columns: cat10_cat25
# Combining Columns: cat7_cat89
# Combining Columns: cat7_cat2
# Combining Columns: cat7_cat72
# Combining Columns: cat7_cat81
# Combining Columns: cat7_cat11
# Combining Columns: cat7_cat1
# Combining Columns: cat7_cat13
# Combining Columns: cat7_cat9
# Combining Columns: cat7_cat3
# Combining Columns: cat7_cat16
# Combining Columns: cat7_cat90
# Combining Columns: cat7_cat23
# Combining Columns: cat7_cat36
# Combining Columns: cat7_cat73
# Combining Columns: cat7_cat103
# Combining Columns: cat7_cat40
# Combining Columns: cat7_cat28
# Combining Columns: cat7_cat111
# Combining Columns: cat7_cat6
# Combining Columns: cat7_cat76
# Combining Columns: cat7_cat50
# Combining Columns: cat7_cat5
# Combining Columns: cat7_cat4
# Combining Columns: cat7_cat14
# Combining Columns: cat7_cat38
# Combining Columns: cat7_cat24
# Combining Columns: cat7_cat82
# Combining Columns: cat7_cat25
# Combining Columns: cat89_cat2
# Combining Columns: cat89_cat72
# Combining Columns: cat89_cat81
# Combining Columns: cat89_cat11
# Combining Columns: cat89_cat1
# Combining Columns: cat89_cat13
# Combining Columns: cat89_cat9
# Combining Columns: cat89_cat3
# Combining Columns: cat89_cat16
# Combining Columns: cat89_cat90
# Combining Columns: cat89_cat23
# Combining Columns: cat89_cat36
# Combining Columns: cat89_cat73
# Combining Columns: cat89_cat103
# Combining Columns: cat89_cat40
# Combining Columns: cat89_cat28
# Combining Columns: cat89_cat111
# Combining Columns: cat89_cat6
# Combining Columns: cat89_cat76
# Combining Columns: cat89_cat50
# Combining Columns: cat89_cat5
# Combining Columns: cat89_cat4
# Combining Columns: cat89_cat14
# Combining Columns: cat89_cat38
# Combining Columns: cat89_cat24
# Combining Columns: cat89_cat82
# Combining Columns: cat89_cat25
# Combining Columns: cat2_cat72
# Combining Columns: cat2_cat81
# Combining Columns: cat2_cat11
# Combining Columns: cat2_cat1
# Combining Columns: cat2_cat13
# Combining Columns: cat2_cat9
# Combining Columns: cat2_cat3
# Combining Columns: cat2_cat16
# Combining Columns: cat2_cat90
# Combining Columns: cat2_cat23
# Combining Columns: cat2_cat36
# Combining Columns: cat2_cat73
# Combining Columns: cat2_cat103
# Combining Columns: cat2_cat40
# Combining Columns: cat2_cat28
# Combining Columns: cat2_cat111
# Combining Columns: cat2_cat6
# Combining Columns: cat2_cat76
# Combining Columns: cat2_cat50
# Combining Columns: cat2_cat5
# Combining Columns: cat2_cat4
# Combining Columns: cat2_cat14
# Combining Columns: cat2_cat38
# Combining Columns: cat2_cat24
# Combining Columns: cat2_cat82
# Combining Columns: cat2_cat25
# Combining Columns: cat72_cat81
# Combining Columns: cat72_cat11
# Combining Columns: cat72_cat1
# Combining Columns: cat72_cat13
# Combining Columns: cat72_cat9
# Combining Columns: cat72_cat3
# Combining Columns: cat72_cat16
# Combining Columns: cat72_cat90
# Combining Columns: cat72_cat23
# Combining Columns: cat72_cat36
# Combining Columns: cat72_cat73
# Combining Columns: cat72_cat103
# Combining Columns: cat72_cat40
# Combining Columns: cat72_cat28
# Combining Columns: cat72_cat111
# Combining Columns: cat72_cat6
# Combining Columns: cat72_cat76
# Combining Columns: cat72_cat50
# Combining Columns: cat72_cat5
# Combining Columns: cat72_cat4
# Combining Columns: cat72_cat14
# Combining Columns: cat72_cat38
# Combining Columns: cat72_cat24
# Combining Columns: cat72_cat82
# Combining Columns: cat72_cat25
# Combining Columns: cat81_cat11
# Combining Columns: cat81_cat1
# Combining Columns: cat81_cat13
# Combining Columns: cat81_cat9
# Combining Columns: cat81_cat3
# Combining Columns: cat81_cat16
# Combining Columns: cat81_cat90
# Combining Columns: cat81_cat23
# Combining Columns: cat81_cat36
# Combining Columns: cat81_cat73
# Combining Columns: cat81_cat103
# Combining Columns: cat81_cat40
# Combining Columns: cat81_cat28
# Combining Columns: cat81_cat111
# Combining Columns: cat81_cat6
# Combining Columns: cat81_cat76
# Combining Columns: cat81_cat50
# Combining Columns: cat81_cat5
# Combining Columns: cat81_cat4
# Combining Columns: cat81_cat14
# Combining Columns: cat81_cat38
# Combining Columns: cat81_cat24
# Combining Columns: cat81_cat82
# Combining Columns: cat81_cat25
# Combining Columns: cat11_cat1
# Combining Columns: cat11_cat13
# Combining Columns: cat11_cat9
# Combining Columns: cat11_cat3
# Combining Columns: cat11_cat16
# Combining Columns: cat11_cat90
# Combining Columns: cat11_cat23
# Combining Columns: cat11_cat36
# Combining Columns: cat11_cat73
# Combining Columns: cat11_cat103
# Combining Columns: cat11_cat40
# Combining Columns: cat11_cat28
# Combining Columns: cat11_cat111
# Combining Columns: cat11_cat6
# Combining Columns: cat11_cat76
# Combining Columns: cat11_cat50
# Combining Columns: cat11_cat5
# Combining Columns: cat11_cat4
# Combining Columns: cat11_cat14
# Combining Columns: cat11_cat38
# Combining Columns: cat11_cat24
# Combining Columns: cat11_cat82
# Combining Columns: cat11_cat25
# Combining Columns: cat1_cat13
# Combining Columns: cat1_cat9
# Combining Columns: cat1_cat3
# Combining Columns: cat1_cat16
# Combining Columns: cat1_cat90
# Combining Columns: cat1_cat23
# Combining Columns: cat1_cat36
# Combining Columns: cat1_cat73
# Combining Columns: cat1_cat103
# Combining Columns: cat1_cat40
# Combining Columns: cat1_cat28
# Combining Columns: cat1_cat111
# Combining Columns: cat1_cat6
# Combining Columns: cat1_cat76
# Combining Columns: cat1_cat50
# Combining Columns: cat1_cat5
# Combining Columns: cat1_cat4
# Combining Columns: cat1_cat14
# Combining Columns: cat1_cat38
# Combining Columns: cat1_cat24
# Combining Columns: cat1_cat82
# Combining Columns: cat1_cat25
# Combining Columns: cat13_cat9
# Combining Columns: cat13_cat3
# Combining Columns: cat13_cat16
# Combining Columns: cat13_cat90
# Combining Columns: cat13_cat23
# Combining Columns: cat13_cat36
# Combining Columns: cat13_cat73
# Combining Columns: cat13_cat103
# Combining Columns: cat13_cat40
# Combining Columns: cat13_cat28
# Combining Columns: cat13_cat111
# Combining Columns: cat13_cat6
# Combining Columns: cat13_cat76
# Combining Columns: cat13_cat50
# Combining Columns: cat13_cat5
# Combining Columns: cat13_cat4
# Combining Columns: cat13_cat14
# Combining Columns: cat13_cat38
# Combining Columns: cat13_cat24
# Combining Columns: cat13_cat82
# Combining Columns: cat13_cat25
# Combining Columns: cat9_cat3
# Combining Columns: cat9_cat16
# Combining Columns: cat9_cat90
# Combining Columns: cat9_cat23
# Combining Columns: cat9_cat36
# Combining Columns: cat9_cat73
# Combining Columns: cat9_cat103
# Combining Columns: cat9_cat40
# Combining Columns: cat9_cat28
# Combining Columns: cat9_cat111
# Combining Columns: cat9_cat6
# Combining Columns: cat9_cat76
# Combining Columns: cat9_cat50
# Combining Columns: cat9_cat5
# Combining Columns: cat9_cat4
# Combining Columns: cat9_cat14
# Combining Columns: cat9_cat38
# Combining Columns: cat9_cat24
# Combining Columns: cat9_cat82
# Combining Columns: cat9_cat25
# Combining Columns: cat3_cat16
# Combining Columns: cat3_cat90
# Combining Columns: cat3_cat23
# Combining Columns: cat3_cat36
# Combining Columns: cat3_cat73
# Combining Columns: cat3_cat103
# Combining Columns: cat3_cat40
# Combining Columns: cat3_cat28
# Combining Columns: cat3_cat111
# Combining Columns: cat3_cat6
# Combining Columns: cat3_cat76
# Combining Columns: cat3_cat50
# Combining Columns: cat3_cat5
# Combining Columns: cat3_cat4
# Combining Columns: cat3_cat14
# Combining Columns: cat3_cat38
# Combining Columns: cat3_cat24
# Combining Columns: cat3_cat82
# Combining Columns: cat3_cat25
# Combining Columns: cat16_cat90
# Combining Columns: cat16_cat23
# Combining Columns: cat16_cat36
# Combining Columns: cat16_cat73
# Combining Columns: cat16_cat103
# Combining Columns: cat16_cat40
# Combining Columns: cat16_cat28
# Combining Columns: cat16_cat111
# Combining Columns: cat16_cat6
# Combining Columns: cat16_cat76
# Combining Columns: cat16_cat50
# Combining Columns: cat16_cat5
# Combining Columns: cat16_cat4
# Combining Columns: cat16_cat14
# Combining Columns: cat16_cat38
# Combining Columns: cat16_cat24
# Combining Columns: cat16_cat82
# Combining Columns: cat16_cat25
# Combining Columns: cat90_cat23
# Combining Columns: cat90_cat36
# Combining Columns: cat90_cat73
# Combining Columns: cat90_cat103
# Combining Columns: cat90_cat40
# Combining Columns: cat90_cat28
# Combining Columns: cat90_cat111
# Combining Columns: cat90_cat6
# Combining Columns: cat90_cat76
# Combining Columns: cat90_cat50
# Combining Columns: cat90_cat5
# Combining Columns: cat90_cat4
# Combining Columns: cat90_cat14
# Combining Columns: cat90_cat38
# Combining Columns: cat90_cat24
# Combining Columns: cat90_cat82
# Combining Columns: cat90_cat25
# Combining Columns: cat23_cat36
# Combining Columns: cat23_cat73
# Combining Columns: cat23_cat103
# Combining Columns: cat23_cat40
# Combining Columns: cat23_cat28
# Combining Columns: cat23_cat111
# Combining Columns: cat23_cat6
# Combining Columns: cat23_cat76
# Combining Columns: cat23_cat50
# Combining Columns: cat23_cat5
# Combining Columns: cat23_cat4
# Combining Columns: cat23_cat14
# Combining Columns: cat23_cat38
# Combining Columns: cat23_cat24
# Combining Columns: cat23_cat82
# Combining Columns: cat23_cat25
# Combining Columns: cat36_cat73
# Combining Columns: cat36_cat103
# Combining Columns: cat36_cat40
# Combining Columns: cat36_cat28
# Combining Columns: cat36_cat111
# Combining Columns: cat36_cat6
# Combining Columns: cat36_cat76
# Combining Columns: cat36_cat50
# Combining Columns: cat36_cat5
# Combining Columns: cat36_cat4
# Combining Columns: cat36_cat14
# Combining Columns: cat36_cat38
# Combining Columns: cat36_cat24
# Combining Columns: cat36_cat82
# Combining Columns: cat36_cat25
# Combining Columns: cat73_cat103
# Combining Columns: cat73_cat40
# Combining Columns: cat73_cat28
# Combining Columns: cat73_cat111
# Combining Columns: cat73_cat6
# Combining Columns: cat73_cat76
# Combining Columns: cat73_cat50
# Combining Columns: cat73_cat5
# Combining Columns: cat73_cat4
# Combining Columns: cat73_cat14
# Combining Columns: cat73_cat38
# Combining Columns: cat73_cat24
# Combining Columns: cat73_cat82
# Combining Columns: cat73_cat25
# Combining Columns: cat103_cat40
# Combining Columns: cat103_cat28
# Combining Columns: cat103_cat111
# Combining Columns: cat103_cat6
# Combining Columns: cat103_cat76
# Combining Columns: cat103_cat50
# Combining Columns: cat103_cat5
# Combining Columns: cat103_cat4
# Combining Columns: cat103_cat14
# Combining Columns: cat103_cat38
# Combining Columns: cat103_cat24
# Combining Columns: cat103_cat82
# Combining Columns: cat103_cat25
# Combining Columns: cat40_cat28
# Combining Columns: cat40_cat111
# Combining Columns: cat40_cat6
# Combining Columns: cat40_cat76
# Combining Columns: cat40_cat50
# Combining Columns: cat40_cat5
# Combining Columns: cat40_cat4
# Combining Columns: cat40_cat14
# Combining Columns: cat40_cat38
# Combining Columns: cat40_cat24
# Combining Columns: cat40_cat82
# Combining Columns: cat40_cat25
# Combining Columns: cat28_cat111
# Combining Columns: cat28_cat6
# Combining Columns: cat28_cat76
# Combining Columns: cat28_cat50
# Combining Columns: cat28_cat5
# Combining Columns: cat28_cat4
# Combining Columns: cat28_cat14
# Combining Columns: cat28_cat38
# Combining Columns: cat28_cat24
# Combining Columns: cat28_cat82
# Combining Columns: cat28_cat25
# Combining Columns: cat111_cat6
# Combining Columns: cat111_cat76
# Combining Columns: cat111_cat50
# Combining Columns: cat111_cat5
# Combining Columns: cat111_cat4
# Combining Columns: cat111_cat14
# Combining Columns: cat111_cat38
# Combining Columns: cat111_cat24
# Combining Columns: cat111_cat82
# Combining Columns: cat111_cat25
# Combining Columns: cat6_cat76
# Combining Columns: cat6_cat50
# Combining Columns: cat6_cat5
# Combining Columns: cat6_cat4
# Combining Columns: cat6_cat14
# Combining Columns: cat6_cat38
# Combining Columns: cat6_cat24
# Combining Columns: cat6_cat82
# Combining Columns: cat6_cat25
# Combining Columns: cat76_cat50
# Combining Columns: cat76_cat5
# Combining Columns: cat76_cat4
# Combining Columns: cat76_cat14
# Combining Columns: cat76_cat38
# Combining Columns: cat76_cat24
# Combining Columns: cat76_cat82
# Combining Columns: cat76_cat25
# Combining Columns: cat50_cat5
# Combining Columns: cat50_cat4
# Combining Columns: cat50_cat14
# Combining Columns: cat50_cat38
# Combining Columns: cat50_cat24
# Combining Columns: cat50_cat82
# Combining Columns: cat50_cat25
# Combining Columns: cat5_cat4
# Combining Columns: cat5_cat14
# Combining Columns: cat5_cat38
# Combining Columns: cat5_cat24
# Combining Columns: cat5_cat82
# Combining Columns: cat5_cat25
# Combining Columns: cat4_cat14
# Combining Columns: cat4_cat38
# Combining Columns: cat4_cat24
# Combining Columns: cat4_cat82
# Combining Columns: cat4_cat25
# Combining Columns: cat14_cat38
# Combining Columns: cat14_cat24
# Combining Columns: cat14_cat82
# Combining Columns: cat14_cat25
# Combining Columns: cat38_cat24
# Combining Columns: cat38_cat82
# Combining Columns: cat38_cat25
# Combining Columns: cat24_cat82
# Combining Columns: cat24_cat25
# Combining Columns: cat82_cat25

# %%
data_types_2 = train_test.dtypes  
cat_cols_2 = list(data_types_2[data_types_2=='object'].index)

# %%
LBL2 = preprocessing.LabelEncoder()
start=time.time()
LE_map2=dict()
for cat_col in cat_cols_2:
    train_test[cat_col] = LBL2.fit_transform(train_test[cat_col])
    LE_map2[cat_col]=dict(zip(LBL2.classes_, LBL2.transform(LBL2.classes_)))
print ('Label enconding finished in %f seconds' % (time.time()-start))
# Out:
# Label enconding finished in 7.941103 seconds

# %%
OHE2 = preprocessing.OneHotEncoder(sparse=True)
start=time.time()
train_test_sparse=OHE2.fit_transform(train_test[cat_cols_2])
print ('One-hot-encoding finished in %f seconds' % (time.time()-start))

print (train_test_sparse.shape)
# Out:
# One-hot-encoding finished in 92.251634 seconds
# (313864, 7000)

# %%
## Add cont15 and cont16 into the con_cols list
con_cols.append('cont15')
con_cols.append('cont16')

# %%
train_test_sparse = sparse.hstack((train_test_sparse,train_test[con_cols]), format='csr')
print (train_test_sparse.shape)
# Out:
# (313864, 7016)

# %%
train_x_2 = train_test_sparse[:train_size]
test_x_2 = train_test_sparse[train_size:]
train_y_2 = np.log(train_test[:train_size].loss.values + 200)
ID = train_test.id[:train_size].values

# %%
rgr2 = xgb.XGBRegressor(seed = 0, 
                       learning_rate = 0.03, 
                       n_estimators = 1500,
                       max_depth=10,
                       min_child_weight=100,
                       colsample_bytree=0.7,
                       subsample=0.7,
                       gamma=0.9,
                       nthread = -1,
                       silent = 1
                      )
rgr2.fit(train_x_2, train_y_2)
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0.9, learning_rate=0.03, max_delta_step=0, max_depth=10,
#        min_child_weight=100, missing=None, n_estimators=1500, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=1, subsample=0.7)

# %% [markdown]
# The training time for this model is pretty long, about 3~4 hrs for one-time training.

# %%
pred_y_2 = np.exp(rgr2.predict(test_x_2)) - 200

results = pd.DataFrame()
results['id'] = full_data[train_size:].id
results['loss'] = pred_y_2
results.to_csv("output/sub2.csv", index=False)
print ("Submission created.")
# Out:
# Submission created.

# %% [markdown]
# Here I submit this sub2.csv to Kaggle, and the Public Score is 1113.44349, the ranking is 99/3055.
